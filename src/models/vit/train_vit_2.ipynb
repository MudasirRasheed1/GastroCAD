# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

zipPath_labeled_images = "/content/drive/MyDrive/labeled_images.zip"  # Path to your zip
extractPath_labeled_images = "/content"  # Where to extract in Colab VM

zipPath_images_splits_csvs = "/content/drive/MyDrive/images_splits_csvs.zip"
extractPath_images_splits_csvs = "/content"

# Unzip
with zipfile.ZipFile(zipPath_labeled_images, 'r') as zip_ref:
    zip_ref.extractall(extractPath_labeled_images)


with zipfile.ZipFile(zipPath_images_splits_csvs, 'r') as zip_ref:
    zip_ref.extractall(extractPath_images_splits_csvs)

# %%
# !pip install timm torchmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 52.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...

# %%
import zipfile
import os
import pandas as pd
from PIL import Image
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.transforms import InterpolationMode
import timm
import torch.nn as nn
import torch.optim as optim
from collections import Counter
from sklearn.preprocessing import LabelEncoder
from torch.cuda.amp import GradScaler, autocast

# Set paths (assuming zip files are already extracted to /content)
IMG_CSV_DIR = "/content/images_splits_csvs"
IMG_ROOT = "/content/labeled_images"

# Load data
df_train = pd.read_csv(os.path.join(IMG_CSV_DIR, "train.csv"))
df_val = pd.read_csv(os.path.join(IMG_CSV_DIR, "val.csv"))
df_test = pd.read_csv(os.path.join(IMG_CSV_DIR, "test.csv"))

# Encode labels
le = LabelEncoder()
df_train['label_enc'] = le.fit_transform(df_train['label'])
df_val['label_enc'] = le.transform(df_val['label'])
df_test['label_enc'] = le.transform(df_test['label'])

NUM_CLASSES = len(le.classes_)

# Image transforms with correct normalization (ImageNet stats)
img_transforms = transforms.Compose([
    transforms.RandomResizedCrop((224, 224), scale=(0.8, 1.0), interpolation=InterpolationMode.BICUBIC),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Custom dataset
class GastroDataset(Dataset):
    def __init__(self, dataframe, img_root, transform=None):
        self.df = dataframe
        self.img_root = os.path.normpath(img_root)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.normpath(os.path.join(self.img_root, str(row['num patient']), row['filename']))
        try:
            image = Image.open(img_path).convert("RGB")
        except FileNotFoundError:
            print(f"Warning: Image not found at {img_path}. Skipping.")
            return torch.zeros(3, 224, 224), row['label_enc']
        except Exception as e:
            print(f"Error loading image {img_path}: {e}. Skipping.")
            return torch.zeros(3, 224, 224), row['label_enc']

        if self.transform:
            image = self.transform(image)
        return image, row['label_enc']

# Dataloaders
batch_size = 16
train_loader = DataLoader(GastroDataset(df_train, IMG_ROOT, img_transforms), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(GastroDataset(df_val, IMG_ROOT, img_transforms), batch_size=batch_size)
test_loader = DataLoader(GastroDataset(df_test, IMG_ROOT, img_transforms), batch_size=batch_size)

# Class weights
class_counts = Counter(df_train['label_enc'])
weights = torch.tensor([1.0 / class_counts[i] for i in range(NUM_CLASSES)], dtype=torch.float32)

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
weights = weights.to(device)

# Model
model = timm.create_model("vit_base_patch16_224", pretrained=True, num_classes=NUM_CLASSES, drop_rate=0.1)
model = model.to(device)

# Loss
criterion = nn.CrossEntropyLoss(weight=weights)

# Optimizer
optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay=1e-4)

# Scheduler
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3)

# Validate function
def validate(model, criterion, loader):
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
    return val_loss / len(loader)

# Train model with early stopping and mixed precision
def train_model(model, criterion, optimizer, scheduler, epochs=30, patience=5):
    scaler = GradScaler()
    best_val_loss = float('inf')
    counter = 0
    train_losses = []
    val_losses = []
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            with autocast():
                outputs = model(images)
                loss = criterion(outputs, labels)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            running_loss += loss.item()
        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)
        val_loss = validate(model, criterion, val_loader)
        val_losses.append(val_loss)
        scheduler.step(val_loss)
        current_lr = scheduler.optimizer.param_groups[0]['lr']
        print(f"Epoch [{epoch+1}/{epochs}] Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Learning Rate: {current_lr:.6f}")
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0
            torch.save(model.state_dict(), "best_vit_model.pth")
            print("Best model saved.")
        else:
            counter += 1
            if counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break
    # Plot loss curve
    plt.plot(range(1, len(train_losses)+1), train_losses, label='Train Loss')
    plt.plot(range(1, len(val_losses)+1), val_losses, label='Val Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.savefig('loss_curve.png')
    plt.show()

# Evaluate function with ROC AUC
def evaluate(model, loader, dataset_name="Test"):
    model.eval()
    all_preds = []
    all_labels = []
    all_probs = []
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probs = torch.softmax(outputs, dim=1)
            _, preds = torch.max(outputs, 1)
            all_probs.extend(probs.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    # Classification report
    print(f"\n--- {dataset_name} Classification Report ---")
    print(classification_report(all_labels, all_preds, target_names=le.classes_, digits=4))
    # Confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, xticklabels=le.classes_, yticklabels=le.classes_, fmt='g', cmap='Blues')
    plt.title(f'{dataset_name} Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.savefig(f"{dataset_name.lower()}_confusion_matrix.png")
    plt.show()
    # ROC AUC
    if NUM_CLASSES > 2:
        roc_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')
    else:
        roc_auc = roc_auc_score(all_labels, all_probs[:,1])
    print(f"{dataset_name} ROC AUC: {roc_auc:.4f}")

# Main
if __name__ == "__main__":
    # Ensure GPU is available
    print(f"Using device: {device}")
    # Train the model
    train_model(model, criterion, optimizer, scheduler, epochs=30, patience=5)
    # Load best model
    model.load_state_dict(torch.load("best_vit_model.pth"))
    model.to(device)
    # Evaluate on validation and test sets
    evaluate(model, val_loader, "Validation")
    evaluate(model, test_loader, "Test")
# Out:
# Using device: cuda
# <ipython-input-6-95fd77f9db3a>:112: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# <ipython-input-6-95fd77f9db3a>:123: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch [1/30] Train Loss: 2.1389, Val Loss: 1.3964, Learning Rate: 0.000100
# Best model saved.
# Epoch [2/30] Train Loss: 1.2565, Val Loss: 1.2619, Learning Rate: 0.000100
# Best model saved.
# Epoch [3/30] Train Loss: 1.0433, Val Loss: 1.0981, Learning Rate: 0.000100
# Best model saved.
# Epoch [4/30] Train Loss: 0.9133, Val Loss: 1.1299, Learning Rate: 0.000100
# Epoch [5/30] Train Loss: 0.8222, Val Loss: 1.0365, Learning Rate: 0.000100
# Best model saved.
# Epoch [6/30] Train Loss: 0.7353, Val Loss: 1.0946, Learning Rate: 0.000100
# ...
