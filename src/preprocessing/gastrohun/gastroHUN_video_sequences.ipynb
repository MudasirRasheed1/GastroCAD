# %%
# !which python
# Out:
# /c/Users/MANNAN SHRAMA/Documents/Sem-4/MLPR/project/GastroCAD/venv/Scripts/python

# %%
import os
import pandas as pd

print(os.getcwd())
# Out:
# c:\Users\MANNAN SHRAMA\Documents\Sem-4\MLPR\project\GastroCAD\src\preprocessing

# %%
notebook_dir = os.getcwd()
sequnce_classification = os.path.join(notebook_dir, "..", "..", "data", "gastroHUN", "official_splits", "sequence_classification.csv")

df = pd.read_csv(sequnce_classification)
print( df.head(20).to_string() )

print(f"\nNo. of rows = no. of video-sequences = {len(df)}")
print(f"No. of unique patients = {df["num_patient"].nunique()}")
# Out:
#     Unnamed: 0  num_patient                                  filename FG1 (Team A) FG2 (Team A) G1 (Team B) G2 (Team B) Complete agreement Triple agreement FG agreement G agreement FG1-G1 agreement FG1-G2 agreement FG2-G1 agreement FG2-G2 agreement set_type
# 0            0            7  546c9947-d45a-45ec-982c-0022ba5c1a3b.mp4           G2           G2          G2          G2                 G2               G2           G2          G2               G2               G2               G2               G2    Train
# 1            1            7  f173a78c-6c93-484c-99c1-33213d262387.mp4           L2           L3          L2          L2                NaN               L2          NaN          L2               L2               L2              NaN              NaN    Train
# 2            2            7  0c14fc9a-3781-4fa9-b8f3-1ece0af92ebd.mp4           L3           L2          L2          L3                NaN              NaN          NaN         NaN              NaN               L3               L2              NaN    Train
# 3            3            7  6ba47cd2-95be-4509-b2f3-49744fda4415.mp4           P3           L3          P3          P3                NaN               P3          NaN          P3               P3               P3              NaN              NaN    Train
# 4            4            7  733eae0c-92b7-4689-879d-346c855f06ea.mp4           G4   OTHERCLASS          G4  OTHERCLASS                NaN              NaN          NaN         NaN               G4              NaN              NaN       OTHERCLASS    Train
# 5            5            7  6045053e-44c9-4f1b-a673-5d0e65d5971f.mp4           L4           L4          L4          L4                 L4               L4           L4          L4               L4               L4               L4               L4    Train
# 6            6            7  c8a55207-6d32-4663-a128-a96cf0340ede.mp4           A4   OTHERCLASS          A4          A4                NaN               A4          NaN          A4               A4               A4              NaN              NaN    Train
# 7            7            7  09c11ec8-7c39-4d83-b439-7d57158ec552.mp4           L4           L5          L4          A4                NaN              NaN          NaN         NaN               L4              NaN              NaN              NaN    Train
# 8            8            7  f2095b22-07e6-40a1-8263-51937925199f.mp4           P5           P5          L5          L5                NaN              NaN           P5          L5              NaN              NaN              NaN              NaN    Train
# 9            9            7  d0c74997-a25b-4913-89af-f4a66da99ee2.mp4           A6           A6          A6          A6                 A6               A6           A6          A6               A6               A6               A6               A6    Train
# 10          10            7  192fddc0-9596-428f-a46b-babd7dc0cdfc.mp4           L6           L6          L6          L6                 L6               L6           L6          L6               L6               L6               L6               L6    Train
# 11          11            8  80a64068-0b9b-41db-b9e8-71f6f382cd4b.mp4           A1           A1          A1          A1                 A1               A1           A1          A1               A1               A1               A1               A1     Test
# 12          12            8  2cc14f04-c4ae-4529-9f34-950482aceb5e.mp4           L1           L1          L1          L1                 L1               L1           L1          L1               L1               L1               L1               L1     Test
# 13          13            8  213867cf-3753-4c35-9d0a-7797a7eadc2b.mp4           G1           G1          G1          G1                 G1               G1           G1          G1               G1               G1               G1               G1     Test
# 14          14            8  a4c31a80-b955-4fe4-8414-ecd7efefbfb4.mp4           P1           P1          P1          P1                 P1               P1           P1          P1               P1               P1               P1               P1     Test
# 15          15            8  c1932ed0-e7ea-454f-95f8-11f4e3a2068b.mp4           G2           A2          A2  OTHERCLASS                NaN              NaN          NaN         NaN              NaN              NaN               A2              NaN     Test
# 16          16            8  0885900d-4f70-490e-8d65-9b73768c41ee.mp4           A2           A2          L2          A2                NaN               A2           A2         NaN              NaN               A2              NaN               A2     Test
# 17          17            8  01b7c97b-389c-40c9-867e-5a54363ce9e4.mp4           P2           G2          P2          P2                NaN               P2          NaN          P2               P2               P2              NaN              NaN     Test
# 18          18            8  ddacdb6a-a2cb-4622-9607-0272a37d76fb.mp4           L2           L2          L3          L2                NaN               L2           L2         NaN              NaN               L2              NaN               L2     Test
# 19          19            8  0c84d1ae-d1bd-4f54-ae7d-b87a7be75a1c.mp4           G3           G3          G3          G3                 G3               G3           G3          G3               G3               G3               G3               G3     Test
#
# No. of rows = no. of video-sequences = 4729
# No. of unique patients = 223

# %%
# Finalize Label: First try "Complete_Agreement", then "FG", then "FG2-G1", and so on
# Performing this on the complete dataset

df["label"] = ( df["Complete agreement"].fillna(df["FG agreement"]) ).fillna( df["FG2-G1 agreement"] ).fillna(df["FG1-G2 agreement"]).fillna(df["G agreement"]).fillna(df["FG1-G1 agreement"]).fillna(df["FG2-G2 agreement"]).fillna(df["Triple agreement"])

# Check if any labels are still missing
missing_labels = df["label"].isnull().sum()
print(f"Missing labels after filling: {missing_labels}")
# 37 rows with missing labels. Drop these rows.

# Drop the rows which still have missing labels (Even if we loose 37 rows, not a big deal)
df = df.dropna(subset=["label"])

# Verifying rows are dropped
missing_labels = df["label"].isnull().sum()
print(f"Missing labels after dropping: {missing_labels}")
# Out:
# Missing labels after filling: 37
# Missing labels after dropping: 0

# %%
print(df["label"].nunique())
print(df["label"].unique())

# *** 23 - 4 = 19
# Out:
# 23
# ['G2' 'L2' 'P3' 'G4' 'L4' 'A4' 'P5' 'A6' 'L6' 'A1' 'L1' 'G1' 'P1' 'A2'
#  'P2' 'G3' 'A3' 'L3' 'A5' 'L5' 'P6' 'OTHERCLASS' 'P4']

# %%
# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")

# Check unique patient IDs
print(f"Total unique patients: {df['num_patient'].nunique()}")

# No. of rows in the dataset
print(f"Number of rows in the dataset: {len(df)}")

print(4729-37)
# Out:
# Number of duplicate rows: 0
# Total unique patients: 223
# Number of rows in the dataset: 4692
# 4692

# %%
print( df["set_type"].unique() )
# Out:
# ['Train' 'Test' 'Validation']

# %%
# Split dataset based on 'set_type'
df_train = df[df["set_type"] == "Train"]
df_val = df[df["set_type"] == "Validation"]
df_test = df[df["set_type"] == "Test"]

# Print dataset sizes
print(f"Train set size: {len(df_train)}\nValidation set size: {len(df_val)}\nTest set size: {len(df_test)}")
# Out:
# Train set size: 3371
# Validation set size: 650
# Test set size: 671

# %%
print(df_train.head().to_string())
# Out:
#    Unnamed: 0  num_patient                                  filename FG1 (Team A) FG2 (Team A) G1 (Team B) G2 (Team B) Complete agreement Triple agreement FG agreement G agreement FG1-G1 agreement FG1-G2 agreement FG2-G1 agreement FG2-G2 agreement set_type label
# 0           0            7  546c9947-d45a-45ec-982c-0022ba5c1a3b.mp4           G2           G2          G2          G2                 G2               G2           G2          G2               G2               G2               G2               G2    Train    G2
# 1           1            7  f173a78c-6c93-484c-99c1-33213d262387.mp4           L2           L3          L2          L2                NaN               L2          NaN          L2               L2               L2              NaN              NaN    Train    L2
# 2           2            7  0c14fc9a-3781-4fa9-b8f3-1ece0af92ebd.mp4           L3           L2          L2          L3                NaN              NaN          NaN         NaN              NaN               L3               L2              NaN    Train    L2
# 3           3            7  6ba47cd2-95be-4509-b2f3-49744fda4415.mp4           P3           L3          P3          P3                NaN               P3          NaN          P3               P3               P3              NaN              NaN    Train    P3
# 4           4            7  733eae0c-92b7-4689-879d-346c855f06ea.mp4           G4   OTHERCLASS          G4  OTHERCLASS                NaN              NaN          NaN         NaN               G4              NaN              NaN       OTHERCLASS    Train    G4

# %%
# df_train.to_csv("../models/train.csv", index=False)
# df_val.to_csv("../models/val.csv", index=False)
# df_test.to_csv("../models/test.csv", index=False)

# %% [markdown]
# ## Performing EDA (on Training data)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a universal style and color palette for all plots
sns.set_theme(style="whitegrid", palette="viridis")

# Count video-sequences per patient (Train set only)
train_patient_counts = df_train["num_patient"].value_counts()
train_patient_counts

plt.figure(figsize=(12, 5))
sns.histplot(train_patient_counts, bins=20, kde=True)
plt.xlabel("Number of video-sequences for a Patient")
plt.ylabel("No. of such patients")
plt.title("Distribution of sequences per Patient (Train Set)")
plt.show()

# %%
# Label Distribution(Train Set)

plt.figure(figsize=(15, 6))
sns.countplot(y=df_train["label"], order=df_train["label"].value_counts().index)
plt.xlabel("Count")
plt.ylabel("Anatomical Landmark")
plt.title("Distribution of Labels in Train Set")
plt.show()

# %%
# Compare Class Distribution Across Train, Validation, and Test Sets

plt.figure(figsize=(18, 6))

# Train distribution
plt.subplot(1, 3, 1)
sns.countplot(y=df_train["label"], order=df_train["label"].value_counts().index)
plt.title("Train Set")

# Validation distribution
plt.subplot(1, 3, 2)
sns.countplot(y=df_val["label"], order=df_train["label"].value_counts().index)
plt.title("Validation Set")

# Test distribution
plt.subplot(1, 3, 3)
sns.countplot(y=df_test["label"], order=df_train["label"].value_counts().index)
plt.title("Test Set")

plt.tight_layout()
plt.show()
