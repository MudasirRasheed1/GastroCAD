# %%
# !which python
# Out:
# /c/Users/MANNAN SHRAMA/Documents/Sem-4/MLPR/project/GastroCAD/venv/Scripts/python

# %%
import os
import pandas as pd

print(os.getcwd())
# Out:
# c:\Users\MANNAN SHRAMA\Documents\Sem-4\MLPR\project\GastroCAD\src\preprocessing

# %%
notebook_dir = os.getcwd()
image_classification = os.path.join(notebook_dir, "..", "..", "data", "gastroHUN", "official_splits", "image_classification.csv")

df = pd.read_csv(image_classification)
print( df.head(30).to_string() )
# Out:
#     Unnamed: 0  num patient                                  filename FG1 (Team A) FG2 (Team A) G1 (Team B) G2 (Team B) Complete agreement Triple agreement FG agreement G agreement FG1-G1 agreement FG1-G2 agreement FG2-G1 agreement FG2-G2 agreement set_type
# 0            0            1  9f8514ab-3839-439e-ad8b-67ee6a6947b0.jpg           A1           A1          A1          A1                 A1               A1           A1          A1               A1               A1               A1               A1    Train
# 1            1            1  b929a2a7-dd6e-4701-a226-f486ca2cc0e2.jpg           L1           A1          A1          A1                NaN               A1          NaN          A1              NaN              NaN               A1               A1    Train
# 2            2            1  fc98b211-07ed-47a9-bfc3-04cd593a2c28.jpg           P1           G1          G1          G1                NaN               G1          NaN          G1              NaN              NaN               G1               G1    Train
# 3            3            1  caa18398-192e-4c1f-bedc-c3c72a7a9180.jpg           G1           G1          G1          G1                 G1               G1           G1          G1               G1               G1               G1               G1    Train
# 4            4            1  b02d8df9-e7d3-4c4a-82fa-620c3bd25c1d.jpg           G2           G2          G2          G2                 G2               G2           G2          G2               G2               G2               G2               G2    Train
# 5            5            1  2de64b53-a39e-4832-82ce-f7e9ac179ec9.jpg           P2           P2          P2          P2                 P2               P2           P2          P2               P2               P2               P2               P2    Train
# 6            6            1  ea731cec-7135-4745-8d5e-8b1a2360254a.jpg           L2           L2          L2          L2                 L2               L2           L2          L2               L2               L2               L2               L2    Train
# 7            7            1  2ffd870a-aca4-4eec-a673-ff24e2a86193.jpg           A3           G3          G2          P2                NaN              NaN          NaN         NaN              NaN              NaN              NaN              NaN    Train
# 8            8            1  3eef327e-ca3f-4ff6-88e7-deeb3fa1ee65.jpg           G3           G3          P3          G3                NaN               G3           G3         NaN              NaN               G3              NaN               G3    Train
# 9            9            1  ff78f9fd-3d1c-4ebe-a59e-b1eafaaa4c85.jpg           P3           P3          P3          P3                 P3               P3           P3          P3               P3               P3               P3               P3    Train
# 10          10            1  71fc4fc5-08b4-4075-b6bd-fc1f102d8e74.jpg           L3           L3          L3          L3                 L3               L3           L3          L3               L3               L3               L3               L3    Train
# 11          11            1  5826854b-7d68-474e-8e31-bcbd48e4a7cc.jpg           P3           P3          A3          A3                NaN              NaN           P3          A3              NaN              NaN              NaN              NaN    Train
# 12          12            1  7ed85654-9178-4c13-baf2-7f5ced2851ff.jpg           A4           G4          G4          A4                NaN              NaN          NaN         NaN              NaN               A4               G4              NaN    Train
# 13          13            1  9fec1014-a2bd-40ba-bf54-95a44cd1e480.jpg           A4           G4          G4          G4                NaN               G4          NaN          G4              NaN              NaN               G4               G4    Train
# 14          14            1  99541e92-a3d6-453a-a8f5-98ad8379f1e6.jpg           G4           G4          G4          A5                NaN               G4           G4         NaN               G4              NaN               G4              NaN    Train
# 15          15            1  6c51a8d7-a9ed-4f73-b9e3-d0621f960721.jpg           A4           G4          G4          A5                NaN              NaN          NaN         NaN              NaN              NaN               G4              NaN    Train
# 16          16            1  91b4007c-b9cd-4ece-8217-090fff84bd72.jpg           A5           L4          L4          L5                NaN              NaN          NaN         NaN              NaN              NaN               L4              NaN    Train
# 17          17            1  d11f1540-bee6-4d07-a220-1cba3d0c00e3.jpg           L5           L4          L4          L5                NaN              NaN          NaN         NaN              NaN               L5               L4              NaN    Train
# 18          18            1  5252d061-9f21-44e4-ab6a-9ca93e81dd4b.jpg           P5           P5          P5          P5                 P5               P5           P5          P5               P5               P5               P5               P5    Train
# 19          19            1  f3315d7a-339b-445c-a687-2bff8b19d596.jpg           A2           A2          A2          A6                NaN               A2           A2         NaN               A2              NaN               A2              NaN    Train
# 20          20            1  f24c23a2-2427-466b-a0da-475834b6ee0b.jpg           L6           A6          L6          L6                NaN               L6          NaN          L6               L6               L6              NaN              NaN    Train
# 21          21            1  e275042e-92ee-4a9c-a527-ab1729f26160.jpg           P6           P6          P6          P6                 P6               P6           P6          P6               P6               P6               P6               P6    Train
# 22          22            1  00770fe2-9158-468b-bc3b-4a1ff6fd2fea.jpg   OTHERCLASS   OTHERCLASS  OTHERCLASS  OTHERCLASS         OTHERCLASS       OTHERCLASS   OTHERCLASS  OTHERCLASS       OTHERCLASS       OTHERCLASS       OTHERCLASS       OTHERCLASS    Train
# 23          23            2  ba191c04-4283-45aa-a3b1-abd544e1d138.jpg   OTHERCLASS   OTHERCLASS  OTHERCLASS  OTHERCLASS         OTHERCLASS       OTHERCLASS   OTHERCLASS  OTHERCLASS       OTHERCLASS       OTHERCLASS       OTHERCLASS       OTHERCLASS     Test
# 24          24            2  9d673269-14a8-40db-98da-bd3a5ae03a71.jpg   OTHERCLASS   OTHERCLASS  OTHERCLASS  OTHERCLASS         OTHERCLASS       OTHERCLASS   OTHERCLASS  OTHERCLASS       OTHERCLASS       OTHERCLASS       OTHERCLASS       OTHERCLASS     Test
# 25          25            2  3dd9a661-047f-4c4c-bdf7-7c081d06ccca.jpg           A2           A1          A2          A2                NaN               A2          NaN          A2               A2               A2              NaN              NaN     Test
# 26          26            2  d53f750a-fc38-47f9-8001-d487e3a5d582.jpg           P1           P1          P1          P1                 P1               P1           P1          P1               P1               P1               P1               P1     Test
# 27          27            2  a39a2625-ea0d-4547-9610-b1237e24bc40.jpg           G1           G1          G1          G1                 G1               G1           G1          G1               G1               G1               G1               G1     Test
# 28          28            2  a55e4755-9588-49a7-a62e-4053b0e6a6ca.jpg           G2           G2          G2  OTHERCLASS                NaN               G2           G2         NaN               G2              NaN               G2              NaN     Test
# 29          29            2  e14ebfdc-631c-48ef-b53f-3f7e6051cf12.jpg           P2           P1          P2          P2                NaN               P2          NaN          P2               P2               P2              NaN              NaN     Test

# %%
# Finalize Label: First try "Complete_Agreement", then "FG", then "FG2-G1", and so on
# Performing this on the complete dataset

df["label"] = ( df["Complete agreement"].fillna(df["FG agreement"]) ).fillna( df["FG2-G1 agreement"] ).fillna(df["FG1-G2 agreement"]).fillna(df["G agreement"]).fillna(df["FG1-G1 agreement"]).fillna(df["FG2-G2 agreement"]).fillna(df["Triple agreement"])

# Check if any labels are still missing
missing_labels = df["label"].isnull().sum()
print(f"Missing labels after filling: {missing_labels}")


# Drop the rows which still have missing labels (Even if we loose 75 rows, not a big deal)
df = df.dropna(subset=["label"])

# Verifying rows are dropped
missing_labels = df["label"].isnull().sum()
print(f"Missing labels after dropping: {missing_labels}")
# Out:
# Missing labels after filling: 75
# Missing labels after dropping: 0

# %%
print(df["label"].nunique())
print(df["label"].unique())
# Out:
# 23
# ['A1' 'G1' 'G2' 'P2' 'L2' 'G3' 'P3' 'L3' 'G4' 'L4' 'P5' 'A2' 'L6' 'P6'
#  'OTHERCLASS' 'P1' 'A3' 'L5' 'A6' 'L1' 'A5' 'P4' 'A4']

# %%
# Check for duplicate rows
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")

# Check unique patient IDs
print(f"Total unique patients: {df['num patient'].nunique()}")

# No. of rows in the dataset
print(f"Number of rows in the dataset: {len(df)}")

print(8834-75)
# Out:
# Number of duplicate rows: 0
# Total unique patients: 387
# Number of rows in the dataset: 8759
# 8759

# %%
# Checking if each and every image file mentioned in the data-set exists

image_base_dir = os.path.join(notebook_dir, "..", "..", "data", "gastroHUN", "Labeled Images")

# Function to check missing images
def check_images_exist(df, image_base_dir):
  missing_images = []
  present_image_count = 0
  for _, row in df.iterrows():
    image_path = os.path.join(image_base_dir, str(row["num patient"]), row["filename"])
    if not os.path.exists(image_path):
      missing_images.append(image_path)
    else:
      present_image_count += 1
  return missing_images, present_image_count

missing_images, present_image_count = check_images_exist(df, image_base_dir)
print(f"Missing images count: {len(missing_images)}")
print(f"Present images count: {present_image_count}")
# Out:
# Missing images count: 8759
# Present images count: 0

# %%
print( df["set_type"].unique() )
# Out:
# ['Train' 'Test' 'Validation']

# %%
# Split dataset based on 'set_type'
df_train = df[df["set_type"] == "Train"]
df_val = df[df["set_type"] == "Validation"]
df_test = df[df["set_type"] == "Test"]

# Print dataset sizes
print(f"Train set size: {len(df_train)}\nValidation set size: {len(df_val)}\nTest set size: {len(df_test)}")

print(df_train.head().to_string())
# Out:
# Train set size: 6108
# Validation set size: 1306
# Test set size: 1345
#    Unnamed: 0  num patient                                  filename FG1 (Team A) FG2 (Team A) G1 (Team B) G2 (Team B) Complete agreement Triple agreement FG agreement G agreement FG1-G1 agreement FG1-G2 agreement FG2-G1 agreement FG2-G2 agreement set_type label
# 0           0            1  9f8514ab-3839-439e-ad8b-67ee6a6947b0.jpg           A1           A1          A1          A1                 A1               A1           A1          A1               A1               A1               A1               A1    Train    A1
# 1           1            1  b929a2a7-dd6e-4701-a226-f486ca2cc0e2.jpg           L1           A1          A1          A1                NaN               A1          NaN          A1              NaN              NaN               A1               A1    Train    A1
# 2           2            1  fc98b211-07ed-47a9-bfc3-04cd593a2c28.jpg           P1           G1          G1          G1                NaN               G1          NaN          G1              NaN              NaN               G1               G1    Train    G1
# 3           3            1  caa18398-192e-4c1f-bedc-c3c72a7a9180.jpg           G1           G1          G1          G1                 G1               G1           G1          G1               G1               G1               G1               G1    Train    G1
# 4           4            1  b02d8df9-e7d3-4c4a-82fa-620c3bd25c1d.jpg           G2           G2          G2          G2                 G2               G2           G2          G2               G2               G2               G2               G2    Train    G2

# %%
# df_train.to_csv("../models/images_splits_csvs/train.csv", index=False)
# df_val.to_csv("../models/images_splits_csvs/val.csv", index=False)
# df_test.to_csv("../models/images_splits_csvs/test.csv", index=False)

# %% [markdown]
# ## Performing EDA (ONLY on the training dataset)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set a universal style and color palette for all plots
sns.set_theme(style="whitegrid", palette="viridis")

# Count images per patient (Train set only)
train_patient_counts = df_train["num patient"].value_counts()
train_patient_counts

plt.figure(figsize=(12, 5))
sns.histplot(train_patient_counts, bins=20, kde=True)
plt.xlabel("Number of Images per Patient")
plt.ylabel("Frequency")
plt.title("Distribution of Images per Patient (Train Set)")
plt.show()

# %%
# Label Distribution(Train Set)

plt.figure(figsize=(15, 6))
sns.countplot(y=df_train["label"], order=df_train["label"].value_counts().index)
plt.xlabel("Count")
plt.ylabel("Anatomical Landmark")
plt.title("Distribution of Labels in Train Set")
plt.show()

# %%
# Compare Class Distribution Across Train, Validation, and Test Sets

plt.figure(figsize=(18, 6))

# Train distribution
plt.subplot(1, 3, 1)
sns.countplot(y=df_train["label"], order=df_train["label"].value_counts().index)
plt.title("Train Set")

# Validation distribution
plt.subplot(1, 3, 2)
sns.countplot(y=df_val["label"], order=df_train["label"].value_counts().index)
plt.title("Validation Set")

# Test distribution
plt.subplot(1, 3, 3)
sns.countplot(y=df_test["label"], order=df_train["label"].value_counts().index)
plt.title("Test Set")

plt.tight_layout()
plt.show()
